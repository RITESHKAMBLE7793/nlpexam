# %%
# Word Sense Disambiguation using WordNet (Lesk Algorithm)

import nltk
from nltk.wsd import lesk
from nltk.corpus import wordnet
from nltk.tokenize import word_tokenize

# Download once
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')

# Input sentence
sentence = "I went to the bank to deposit money"

# Target word
word = "bank"

# Tokenize sentence
tokens = word_tokenize(sentence)

# Apply Lesk Algorithm
sense = lesk(tokens, word)

# Output
print("Sentence:", sentence)
print("Word:", word)

if sense:
    print("Predicted Meaning:", sense.definition())
    print("Synset:", sense.name())
else:
    print("No sense found")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\kokar\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\kokar\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\kokar\AppData\Roaming\nltk_data...
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[1], line 20
#      17 word = "bank"
#      19 # Tokenize sentence
# ---> 20 tokens = word_tokenize(sentence)
#      22 # Apply Lesk Algorithm
#      23 sense = lesk(tokens, word)
#
# File c:\Users\kokar\AppData\Local\Programs\Python\Python310\lib\site-packages\nltk\tokenize\__init__.py:142, in word_tokenize(text, language, preserve_line)
#     127 def word_tokenize(text, language="english", preserve_line=False):
#     128     """
#     129     Return a tokenized copy of *text*,
#     130     using NLTK's recommended word tokenizer
#    (...)
#     140     :type preserve_line: bool
#     141     """
# --> 142     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     143     return [
#     144         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#     145     ]
#
# File c:\Users\kokar\AppData\Local\Programs\Python\Python310\lib\site-packages\nltk\tokenize\__init__.py:119, in sent_tokenize(text, language)
#     109 def sent_tokenize(text, language="english"):
#     110     """
#     111     Return a sentence-tokenized copy of *text*,
#     112     using NLTK's recommended sentence tokenizer
#    (...)
#     117     :param language: the model name in the Punkt corpus
#     118     """
# --> 119     tokenizer = _get_punkt_tokenizer(language)
#     120     return tokenizer.tokenize(text)
#
# File c:\Users\kokar\AppData\Local\Programs\Python\Python310\lib\site-packages\nltk\tokenize\__init__.py:105, in _get_punkt_tokenizer(language)
#      96 @functools.lru_cache
#      97 def _get_punkt_tokenizer(language="english"):
#      98     """
#      99     A constructor for the PunktTokenizer that utilizes
#     100     a lru cache for performance.
#    (...)
#     103     :type language: str
#     104     """
# --> 105     return PunktTokenizer(language)
#
# File c:\Users\kokar\AppData\Local\Programs\Python\Python310\lib\site-packages\nltk\tokenize\punkt.py:1746, in PunktTokenizer.__init__(self, lang)
#    1744 def __init__(self, lang="english"):
#    1745     PunktSentenceTokenizer.__init__(self)
# -> 1746     self.load_lang(lang)
#
# File c:\Users\kokar\AppData\Local\Programs\Python\Python310\lib\site-packages\nltk\tokenize\punkt.py:1751, in PunktTokenizer.load_lang(self, lang)
#    1748 def load_lang(self, lang="english"):
#    1749     from nltk.data import find
# -> 1751     lang_dir = find(f"tokenizers/punkt_tab/{lang}/")
#    1752     self._params = load_punkt_params(lang_dir)
#    1753     self._lang = lang
#
# File c:\Users\kokar\AppData\Local\Programs\Python\Python310\lib\site-packages\nltk\data.py:738, in find(resource_name, paths)
#     736 sep = "*" * 70
#     737 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 738 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource 'punkt_tab' not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load 'tokenizers/punkt_tab/english/'
#
#   Searched in:
#     - 'C:\\Users\\kokar/nltk_data'
#     - 'c:\\Users\\kokar\\AppData\\Local\\Programs\\Python\\Python310\\nltk_data'
#     - 'c:\\Users\\kokar\\AppData\\Local\\Programs\\Python\\Python310\\share\\nltk_data'
#     - 'c:\\Users\\kokar\\AppData\\Local\\Programs\\Python\\Python310\\lib\\nltk_data'
#     - 'C:\\Users\\kokar\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
